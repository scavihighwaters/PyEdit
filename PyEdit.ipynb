# %%
print(r"""                                                                    
,-.----.                                                             
\   /  \                   ,---,.                           ___     
|   :    \                ,'  .' |       ,---,   ,--,      ,--.'|_   
|   |  .\ :             ,---.'   |     ,---.'| ,--.'|      |  | :,'  
.   :  |: |             |   |   .'     |   | : |  |,       :  : ' :  
|   |   \ :       .--,  :   :  |-,     |   | | `--'_     .;__,'  /   
|   : .   /     /_ ./|  :   |  ;/|   ,--.__| | ,' ,'|    |  |   |    
;   | |`-'   , ' , ' :  |   :   .'  /   ,'   | '  | |    :__,'| :    
|   | ;     /___/ \: |  |   |  |-, .   '  /  | |  | :      '  : |__  
:   ' |      .  \  ' |  '   :  ;/| '   ; |:  | '  : |__    |  | '.'| 
:   : :       \  ;   :  |   |    \ |   | '/  ' |  | '.'|   ;  :    ; 
|   | :        \  \  ;  |   :   .' |   :    :| ;  :    ;   |  ,   /  
`---'.|         :  \  \ |   | ,'    \   \  /   |  ,   /     ---`-'   
  `---`          \  ' ; `----'       `----'     ---`-'               
                  `--`                                           """)

print(r""" AN IMAGE EDITOR USING PYTHON

Libraries used:
Numpy and Matplotlib

This image editor can be used to perform simple image editing using image processing in python.
 
.......................................................................................................................................................""")

#MAIN
def prog():    
    #image path as input
    img_path = input("Enter image path:")
    
    import numpy as np
    import matplotlib.pyplot as plt
    # %matplotlib inline
    
    #original image
    original_img = plt.imread(img_path)
    #displaying original image
    plt.imshow(original_img)
    plt.title('Original Image')
    plt.axis('off')
    plt.show()
    
    #edited image 
    def edited_img(img, title):
        plt.imshow(img)
        plt.axis('off')
        plt.title(title)
        plt.show()
    
    #exiting fn
    class TerminateProgram(Exception):
        pass
    
    def terminate_program():
        print("\n\n\nThanks for using Pyedit :)")
        raise TerminateProgram
    
    
    def main_tool():
        #ui
        print(f"Options:\n [1]: MORPH :\n [2]: FILTER :\n [3]: ADJUST :\n")
        opn = int(input("#choose using 1-3"))
        
        if opn == 1:
            #MORPH
            print(f"Options:\n [1]: FLIP :\n [2]: ROTATE :\n [3]: CROP :\n")
            x = int(input("#choose using 1-3"))
            #func
            def flip_horizontal(img):
                return np.fliplr(img)
            def flip_vertical(img):
                return np.flipud(img)
            def rotate(img, angle):
                return np.rot90(img, k=int(angle / 90) % 4)
            def crop(img, top, bottom, right, left):
                return img[top:-bottom, left:-right]
            def rotate(img, angle):
                    rows, cols, _ = img.shape
                    img_rotated = np.zeros((rows, cols, 3), dtype=np.uint8)
                    cos_a = np.cos(angle)
                    sin_a = np.sin(angle)
                    for r in range(rows):
                        for c in range(cols):
                            x = r - rows // 2
                            y = c - cols // 2
                            x_new = x * cos_a - y * sin_a
                            y_new = x * sin_a + y * cos_a
                            x_new = int(x_new + rows // 2)
                            y_new = int(y_new + cols // 2)
                            if x_new >= 0 and x_new < rows and y_new >= 0 and y_new < cols:
                                img_rotated[r][c] = img[x_new][y_new]
                    return img_rotated
            #switch
            if x == 1:
                print(f"Options:\n [1]: FLIP HORIZONTAL :\n [2]: FLIP VERTICAL :")
                y = int(input("#choose using 1-2"))
                if y == 1:
                    #flip store
                    flip_img_h = flip_horizontal(original_img)
                    #display
                    edited_img(flip_img_h, "Image Flipped Horizontaly")
                if y == 2:
                    #flip store
                    flip_img_v = flip_vertical(original_img)
                    #display
                    edited_img(flip_img_v, "Image Flipped Vertically")
            if x == 2:
                #rotation
                #input
                x = int(input("Enter degree:"))
                x = 180/x
                angle = np.pi / x
                
                #display
                img_rotated = rotate(original_img, angle)
                #plt.imshow(img_rotated)
                edited_img(img_rotated,"Rotated image")
                 
            if x == 3:
                # crop dimensions
                print("Enter values to be cropped (in %age):")
                top = int(input("top: "))
                bottom = int(input("bottom: "))
                left = int(input("left: "))
                right = int(input("right: "))
                #crop store
                crop_img = crop(original_img, top, bottom, right, left)
                #display
                edited_img(crop_img, "Cropped Image")
        if opn == 2:
            #filter
        
            #grayscale
            img = np.dot(original_img[..., :3], [0.2989, 0.5870, 0.1140])
            #options
            print("FILTERS:")
            print("1: Greys\n"
                "2: Purples\n"
                "3: Blues\n"
                "4: Greens\n"
                "5: Oranges\n"
                "6: Reds\n"
                "7: YlOrBr\n"
                "8: YlOrRd\n"
                "9: OrRd\n"
                "10: PuRd\n"
                "11: RdPu\n"
                "12: BuPu\n"
                "13: GnBu\n"
                "14: PuBu\n"
                "15: YlGnBu\n"
                "16: PuBuGn\n"
                "17: BuGn\n"
                "18: YlGn\n"
                "19: Binary\n"
                "20: Gist Yarg\n"
                "21: Gist Gray\n"
                "22: Gray\n"
                "23: Bone\n"
                "24: Pink\n"
                "25: Spring\n"
                "26: Summer\n"
                "27: Autumn\n"
                "28: Winter\n"
                "29: Cool\n"
                "30: Wistia\n"
                "31: Hot\n"
                "32: Afmhot\n"
                "33: Gist Heat\n"
                "34: Copper\n"
                "35: PiYG\n"
                "36: PRGn\n"
                "37: BrBG\n"
                "38: PuOr\n"
                "39: RdGy\n"
                "40: RdBu\n"
                "41: RdYlBu\n"
                "42: RdYlGn\n"
                "43: Spectral\n"
                "44: Coolwarm\n"
                "45: Bwr\n"
                "46: Seismic\n"
                "47: Twilight\n"
                "48: Twilight Shifted\n"
                "49: HSV\n"
                "50: Pastel1\n"
                "51: Pastel2\n"
                "52: Paired\n"
                "53: Accent\n"
                "54: Dark2\n"
                "55: Set1\n"
                "56: Set2\n"
                "57: Set3\n"
                "58: Tab10\n"
                "59: Tab20\n"
                "60: Tab20b\n"
                "61: Tab20c\n"
                "62: Flag\n"
                "63: Prism\n"
                "64: Ocean\n"
                "65: Gist Earth\n"
                "66: Terrain\n"
                "67: Gist Stern\n"
                "68: Gnuplot\n"
                "69: Gnuplot2\n"
                "70: CMRmap\n"
                "71: Cubehelix\n"
                "72: Brg\n"
                "73: Gist Rainbow\n"
                "74: Rainbow\n"
                "75: Jet\n"
                "76: Turbo\n"
                "77: Nipy Spectral\n"
                "78: Gist Ncar\n"
                "79: Viridis\n"
                "80: Plasma\n"
                "81: Inferno\n"
                "82: Magma\n"
                "83: Cividis")
        
            #options_dict
            options = {
                1: 'Greys', 2: 'Purples', 3: 'Blues', 4: 'Greens', 5: 'Oranges', 6: 'Reds',
                7: 'YlOrBr', 8: 'YlOrRd', 9: 'OrRd', 10: 'PuRd', 11: 'RdPu', 12: 'BuPu',
                13: 'GnBu', 14: 'PuBu', 15: 'YlGnBu', 16: 'PuBuGn', 17: 'BuGn', 18: 'YlGn',
                19: 'binary', 20: 'gist_yarg', 21: 'gist_gray', 22: 'gray', 23: 'bone', 24: 'pink',
                25: 'spring', 26: 'summer', 27: 'autumn', 28: 'winter', 29: 'cool', 30: 'Wistia',
                31: 'hot', 32: 'afmhot', 33: 'gist_heat', 34: 'copper',
                35: 'PiYG', 36: 'PRGn', 37: 'BrBG', 38: 'PuOr', 39: 'RdGy', 40: 'RdBu',
                41: 'RdYlBu', 42: 'RdYlGn', 43: 'Spectral', 44: 'coolwarm', 45: 'bwr', 46: 'seismic',
                47: 'twilight', 48: 'twilight_shifted', 49: 'hsv',
                50: 'Pastel1', 51: 'Pastel2', 52: 'Paired', 53: 'Accent',
                54: 'Dark2', 55: 'Set1', 56: 'Set2', 57: 'Set3',
                58: 'tab10', 59: 'tab20', 60: 'tab20b', 61: 'tab20c',
                62: 'flag', 63: 'prism', 64: 'ocean', 65: 'gist_earth', 66: 'terrain', 67: 'gist_stern',
                68: 'gnuplot', 69: 'gnuplot2', 70: 'CMRmap', 71: 'cubehelix', 72: 'brg',
                73: 'gist_rainbow', 74: 'rainbow', 75: 'jet', 76: 'turbo', 77: 'nipy_spectral',
                78: 'gist_ncar', 79: 'viridis', 80: 'plasma', 81: 'inferno', 82: 'magma', 83: 'cividis'}
            #filter options
            filter = options[int(input("#Choose using 1-83"))]
            #filter_func
            plt.imshow(img, cmap=filter)
            plt.axis('off')
            plt.title("EDITED IMAGE \n FILTER USED:"+filter)
            plt.show()
        if opn == 3:
            #adjust
            print(f"Options:\n [1]: EXPOSURE :\n [2]: INTENSITY :\n [3]: NOISE :\n")
            var = int(input("#choose using 1-3"))
            if var == 1:
                x = int(input("Enter tint %age"))
                def tint(original_img, percent=(x/100)):
                    return(original_img + (np.ones(original_img.shape) - original_img) * percent).astype("uint8")
                
                plt.imshow(tint(original_img))
                plt.title('Adjusted Exposure')
                plt.axis('off')
                plt.show()
            elif var == 2:
                thr_int = int(input("Enter Intensity (0-255) :"))
                img_thr = (original_img > thr_int) * 255
                fig = plt.figure(figsize=(15, 15))
                img_all = np.concatenate((original_img, img_thr), axis=1)
                edited_img(img_all,"Intensity Changed")
            elif var == 3:
                img = original_img
                noise = np.random.normal(0, 50, img.shape) 
                img_noised = img + noise
                img_noised = np.clip(img_noised, 0, 255).astype(np.uint8)
                    
                plt.imshow(img_noised)
                plt.title("Edited Image\n Noise")
                plt.axis('off')  
                plt.show()
    
    main_tool()
prog()

    
print("\n\n\n Thanks for using PyEdit.")
# Out:
#
# ,-.----.
# \   /  \                   ,---,.                           ___
# |   :    \                ,'  .' |       ,---,   ,--,      ,--.'|_
# |   |  .\ :             ,---.'   |     ,---.'| ,--.'|      |  | :,'
# .   :  |: |             |   |   .'     |   | : |  |,       :  : ' :
# |   |   \ :       .--,  :   :  |-,     |   | | `--'_     .;__,'  /
# |   : .   /     /_ ./|  :   |  ;/|   ,--.__| | ,' ,'|    |  |   |
# ;   | |`-'   , ' , ' :  |   :   .'  /   ,'   | '  | |    :__,'| :
# |   | ;     /___/ \: |  |   |  |-, .   '  /  | |  | :      '  : |__
# :   ' |      .  \  ' |  '   :  ;/| '   ; |:  | '  : |__    |  | '.'|
# :   : :       \  ;   :  |   |    \ |   | '/  ' |  | '.'|   ;  :    ;
# |   | :        \  \  ;  |   :   .' |   :    :| ;  :    ;   |  ,   /
# `---'.|         :  \  \ |   | ,'    \   \  /   |  ,   /     ---`-'
#   `---`          \  ' ; `----'       `----'     ---`-'
#                   `--`
#  AN IMAGE EDITOR USING PYTHON
#
# Libraries used:
# ...
